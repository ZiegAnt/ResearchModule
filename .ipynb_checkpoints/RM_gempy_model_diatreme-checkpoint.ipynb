# %% [markdown]
# # Simplyfied geologic model of a volcanic diatreme structure

# %% [markdown]
# ## written by Anton Ziegon

# %% [markdown]
# Imports

# %%
# Imports and settings
# %matplotlib inline
from pyvista import set_plot_theme
set_plot_theme('document')

import gempy as gp

# Importing auxiliary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Setting options
np.random.seed(1515)
pd.set_option('precision', 2)
# Out:
# Not subsurface compatibility available

# %% [markdown]
# ### Loading surface points and orientations

# %%
geo_model_diatreme = gp.create_model('simple_diatreme')

# Importing the data from CSV-files and setting extent and resolution
gp.init_data(geo_model_diatreme, [0, 150, 0, 150., -60, 0], [40, 40, 40],
             path_i='RM_surface_points_diatreme_easy.csv', path_o='RM_orientations_diatreme_easy.csv',
             default_values=True)
# Out:
# Active grids: ['regular']
# simple_diatreme  2022-11-30 15:57

# %% [markdown]
# Sortring Formations

# %%
geo_model_diatreme.series
# Out:
#           order_series BottomRelation isActive isFault isFinite
# Lith               1.0        Erosion     True   False    False
# Diatreme           NaN          Onlap      NaN     NaN      NaN

# %%
gp.map_stack_to_surfaces(geo_model_diatreme,
                         {"Lith":('Diatreme','basement')},
                         remove_unused_series=True)
geo_model_diatreme.set_bottom_relation('Lith',bottom_relation='Erosion')
geo_model_diatreme.series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_736\982207564.py in <module>
# ----> 1 gp.map_stack_to_surfaces(geo_model_diatreme,
#       2                          {"Lith":('Diatreme','basement')},
#       3                          remove_unused_series=True)
#       4 geo_model_diatreme.set_bottom_relation('Lith',bottom_relation='Erosion')
#       5 geo_model_diatreme.series
#
# ~\anaconda3\envs\agp\lib\site-packages\gempy\gempy_api.py in map_stack_to_surfaces(geo_model, mapping_object, set_features, sort_geometric_data, remove_unused_series)
#      90     """
#      91
# ---> 92     geo_model.map_stack_to_surfaces(mapping_object, set_features, sort_geometric_data, remove_unused_series)
#      93     return geo_model._surfaces
#      94
#
# ~\anaconda3\envs\agp\lib\site-packages\gempy\core\model.py in map_stack_to_surfaces(self, mapping_object, set_series, sort_geometric_data, remove_unused_series, twofins)
#     911             if type(mapping_object) is dict:
#     912                 series_list = list(mapping_object.keys())
# --> 913                 self._stack.add_series(series_list)
#     914             elif isinstance(mapping_object, pn.Categorical):
#     915                 series_list = mapping_object['series'].values
#
# ~\anaconda3\envs\agp\lib\site-packages\gempy\core\data_modules\stack.py in add_series(self, series_list, reset_order_series)
#     296
#     297         # Remove from the list categories that already exist
# --> 298         series_list = series_list[~np.in1d(series_list, self.df.index.categories)]
#     299
#     300         idx = self.df.index.add_categories(series_list)
#
# AttributeError: 'Index' object has no attribute 'categories'

# %%
geo_model_diatreme.surfaces.colors.change_colors({'Diatreme': '#8b4513',
                                                'basement':'#8b8878'})
geo_model_diatreme.surfaces
# Out:
#     surface    series  order_surfaces    color  id
# 0  Diatreme  Diatreme               1  #8b4513   1
# 1  basement  Basement               1  #8b8878   2

# %% [markdown]
# Set random Topography

# %%
geo_model_diatreme.set_topography(source='random')
# Out:
# [-12.   0.]
# Active grids: ['regular' 'topography']
# Grid Object. Values:
# array([[  1.875     ,   1.875     , -59.25      ],
#        [  1.875     ,   1.875     , -57.75      ],
#        [  1.875     ,   1.875     , -56.25      ],
#        ...,
#        [150.        , 142.30769231,  -6.96252759],
#        [150.        , 146.15384615,  -7.05010959],
#        [150.        , 150.        ,  -6.23399294]])

# %% [markdown]
# ### First inspection of data points in 2D and 3D

# %%
plot = gp.plot_2d(geo_model_diatreme, show_lith=False, show_boundaries=False, show_topography=False)
plt.show()

gpv = gp.plot_3d(geo_model_diatreme, image=False, plotter_type='background', show_topography=False)
# Out:
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\pyvista\utilities\helpers.py:475: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   warnings.warn(

# %% [markdown]
# ### Set interpolator and solve model

# %%
gp.set_interpolator(geo_model_diatreme, compile_theano=True, theano_optimizer='fast_compile')
sol = gp.compute_model(geo_model_diatreme, debug=False)
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '15836' (I am process '736')
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\theano\scan_module\scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range             220.45
# $C_o$            1157.14
# drift equations   [3, 3]

# %% [markdown]
# Visulaizing solution in 3D

# %%
ver, sim = gp.get_surfaces(geo_model_diatreme)
gpv = gp.plot_3d(geo_model_diatreme, show_data=False, show_lith=False, image=False, plotter_type='background')
# Out:
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\pyvista\plotting\tools.py:571: PyvistaDeprecationWarning: The usage of `parse_color` is deprecated in favor of the new `Color` class.
#   warnings.warn(

# %% [markdown]
# Visulizing cross sections for further inspestion

# %%
gp.plot_2d(geo_model_diatreme, show_data=True, direction='y', cell_number=10,
           plot_data=True, show_topography=True, section_names=['topography'])
plt.show()
# Out:
# C:\Users\azieg\anaconda3\envs\agp\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()
